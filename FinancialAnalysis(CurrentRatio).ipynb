# %%
import pandas as pd

# %%
path = "C:/Users/Ufuk Altan/Downloads/Downloads/Data Science/PyFinance/04 - Intrinsic Value/"
df = pd.read_csv(path + '50-current-ratio.csv', index_col = 0)
df.head()
# Out:
#             AAPL  MSFT  AMZN  GOOG    FB  TSLA  BRK.A     V   JNJ  WMT  ...  \
# 2020-09-30  1.36  2.53  1.11  3.41  5.51  1.64   0.27  1.91  1.48  NaN  ...
# 2020-06-30  1.47  2.52  1.18  3.41  6.03  1.25   0.30  1.55  1.25  NaN  ...
# 2020-03-31  1.50  2.90  1.08  3.66  4.60  1.24   0.33  1.25  1.31  NaN  ...
# 2019-12-31  1.60  2.80  1.10  3.37  4.40  1.14   0.39  1.27  1.26  NaN  ...
# 2019-09-30  1.54  2.85  1.10  3.78  4.66  1.08   0.44  1.56  1.26  NaN  ...
#
#             COST   CVX   LLY   MCD   DHR  MDT   NEE   TXN   HON   UPS
# 2020-09-30   NaN  1.26  1.36  1.07  2.08  NaN  0.57  4.24  1.64  1.29
# 2020-06-30   NaN  1.14  1.22  0.91  2.20  NaN  0.61  3.92  1.63  1.24
# 2020-03-31   NaN  1.01  1.11  1.90  1.32  NaN  0.71  3.49  1.30  1.22
# 2019-12-31   NaN  1.07  1.16  0.98  5.19  NaN  0.54  4.13  1.34  1.11
# 2019-09-30   NaN  1.12  1.17  0.84  3.43  NaN  0.58  4.34  1.32  1.11
#
# [5 rows x 50 columns]

# %%
df.index = pd.to_datetime(df.index)
df.index
# Out:
# DatetimeIndex(['2020-09-30', '2020-06-30', '2020-03-31', '2019-12-31',
#                '2019-09-30', '2019-06-30', '2019-03-31', '2018-12-31',
#                '2018-09-30', '2018-06-30',
#                ...
#                '2007-05-31', '2007-02-28', '2006-11-30', '2006-08-31',
#                '2006-05-31', '2006-02-28', '2005-11-30', '2005-08-31',
#                '2005-05-31', '2005-02-28'],
#               dtype='datetime64[ns]', length=191, freq=None)

# %%
df.loc[:'2010-01-01']
# Out:
#             AAPL  MSFT  AMZN   GOOG   FB  TSLA  BRK.A     V   JNJ   WMT  ...  \
# 2009-12-31  2.55  2.04  1.33  10.62  0.0   0.0   0.45  2.41  1.82   NaN  ...
# 2009-09-30  2.74  1.82  1.40  11.35  NaN   0.0   0.42  2.08  1.85   NaN  ...
# 2009-06-30  2.11  1.82  1.46  11.91  NaN   0.0   0.40  2.16  1.79   NaN  ...
# 2009-03-31  2.46  1.71  1.40  10.11  NaN   NaN   0.42  1.94  1.63   NaN  ...
# 2008-12-31  2.38  1.59  1.30   8.77  0.0   0.0   0.42  1.75  1.65   NaN  ...
# 2008-09-30  2.64  1.53  1.41   8.08  NaN   NaN   0.50  1.56  1.61   NaN  ...
# 2008-06-30  3.04  1.45  1.32   6.96  NaN   NaN   0.49  1.77  1.64   NaN  ...
# 2008-03-31  2.78  1.54  1.12   6.29  NaN   NaN   0.52  1.73  1.53   NaN  ...
# 2007-12-31  2.49  1.71  1.39   8.49  NaN   NaN   0.58  1.12  1.51   NaN  ...
# 2007-09-30  2.37  1.58  1.48   8.83  NaN   NaN   0.60  0.76  1.50   NaN  ...
# 2007-06-30  2.68  1.69  1.48  11.26  NaN   NaN   0.60  0.00  1.36   NaN  ...
# ...

# %%
col = df.resample('Q', convention = 'end').agg('mean').transpose()['2020-09-30']

# %%
col > 1
# Out:
# AAPL      True
# MSFT      True
# AMZN      True
# GOOG      True
# FB        True
# TSLA      True
# BRK.A    False
# V         True
# JNJ       True
# WMT      False
# JPM      False
# MA        True
# PG       False
# UNH      False
# DIS       True
# NVDA      True
# HD        True
# PYPL      True
# BAC      False
# VZ        True
# ADBE      True
# CMCSA    False
# NFLX      True
# KO        True
# NKE       True
# MRK       True
# PEP      False
# T        False
# PFE       True
# INTC      True
# CRM       True
# ABT       True
# ORCL      True
# ABBV     False
# CSCO      True
# TMO       True
# AVGO      True
# XOM      False
# ACN       True
# QCOM      True
# COST      True
# CVX       True
# LLY       True
# MCD       True
# DHR       True
# MDT       True
# NEE      False
# TXN       True
# HON       True
# UPS       True
# Name: 2020-09-30 00:00:00, dtype: bool
