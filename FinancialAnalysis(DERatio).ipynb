# %%
import pandas as pd

# %%
path = "C:/Users/Ufuk Altan/Downloads/Downloads/Data Science/PyFinance/04 - Intrinsic Value/"
df = pd.read_csv(path + '50-de-ratio.csv', index_col = 0)
df.head()
# Out:
#             AAPL  MSFT  AMZN  GOOG    FB  TSLA  BRK.A     V   JNJ  WMT  ...  \
# 2020-09-30  3.96  1.44  2.41  0.41  0.24  1.71   0.98  1.24  1.65  NaN  ...
# 2020-06-30  3.39  1.55  2.50  0.34  0.27  2.56   0.98  1.19  1.52  NaN  ...
# 2020-03-31  3.09  1.49  2.39  0.34  0.31  2.71   1.03  1.11  1.53  NaN  ...
# 2019-12-31  2.80  1.57  2.63  0.37  0.32  3.60   0.91  1.12  1.65  NaN  ...
# 2019-09-30  2.74  1.63  2.52  0.35  0.32  3.77   0.96  1.09  1.67  NaN  ...
#
#             COST   CVX    LLY   MCD   DHR  MDT   NEE   TXN   HON    UPS
# 2020-09-30   NaN  0.69   7.80 -6.98  0.92  NaN  2.01  1.19  2.47  10.13
# 2020-06-30   NaN  0.66   8.82 -6.28  0.97  NaN  1.93  1.28  2.46  13.18
# 2020-03-31   NaN  0.63  11.86 -6.44  1.22  NaN  1.95  1.24  2.21  17.38
# 2019-12-31   NaN  0.64  13.56 -6.79  1.05  NaN  1.85  1.02  2.14  16.62
# 2019-09-30   NaN  0.64   9.94 -6.33  0.85  NaN  1.84  1.00  2.28   8.56
#
# [5 rows x 50 columns]

# %%
df.index = pd.to_datetime(df.index)
df.index
# Out:
# DatetimeIndex(['2020-09-30', '2020-06-30', '2020-03-31', '2019-12-31',
#                '2019-09-30', '2019-06-30', '2019-03-31', '2018-12-31',
#                '2018-09-30', '2018-06-30',
#                ...
#                '2007-05-31', '2007-02-28', '2006-11-30', '2006-08-31',
#                '2006-05-31', '2006-02-28', '2005-11-30', '2005-08-31',
#                '2005-05-31', '2005-02-28'],
#               dtype='datetime64[ns]', length=191, freq=None)

# %%
df.sort_index(ascending = False)
# Out:
#             AAPL  MSFT   AMZN  GOOG    FB  TSLA  BRK.A     V   JNJ   WMT  ...  \
# 2020-11-30   NaN   NaN    NaN   NaN   NaN   NaN    NaN   NaN   NaN   NaN  ...
# 2020-10-31   NaN   NaN    NaN   NaN   NaN   NaN    NaN   NaN   NaN  1.87  ...
# 2020-09-30  3.96  1.44   2.41  0.41  0.24  1.71   0.98  1.24  1.65   NaN  ...
# 2020-08-31   NaN   NaN    NaN   NaN   NaN   NaN    NaN   NaN   NaN   NaN  ...
# 2020-07-31   NaN   NaN    NaN   NaN   NaN   NaN    NaN   NaN   NaN  1.92  ...
# ...          ...   ...    ...   ...   ...   ...    ...   ...   ...   ...  ...
# 2005-05-31   NaN   NaN    NaN   NaN   NaN   NaN    NaN   NaN   NaN   NaN  ...
# 2005-04-30   NaN   NaN    NaN   NaN   NaN   NaN    NaN   NaN   NaN  1.59  ...
# 2005-03-31  0.58  0.40 -16.26  0.13   NaN   NaN   1.21   NaN  0.62   NaN  ...
# 2005-02-28   NaN   NaN    NaN   NaN   NaN   NaN    NaN   NaN   NaN   NaN  ...
# 2005-01-31   NaN   NaN    NaN   NaN   NaN   NaN    NaN   NaN   NaN  1.43  ...
#
# ...

# %%
df.resample('Q', convention = 'end').agg('mean')
# Out:
#             AAPL  MSFT    AMZN  GOOG    FB  TSLA  BRK.A     V   JNJ   WMT  \
# 2005-03-31  0.58  0.40  -16.26  0.13   NaN   NaN   1.21   NaN  0.62  1.43
# 2005-06-30  0.54  0.47  -41.64  0.14   NaN   NaN   1.21   NaN  0.55  1.59
# 2005-09-30  0.55  0.48  471.00  0.08   NaN   NaN   1.20   NaN  0.54  1.61
# 2005-12-31  0.69  0.52   14.02  0.09   NaN   NaN   1.17   NaN  0.52  1.64
# 2006-03-31  0.60  0.59    8.23  0.10   NaN   NaN   1.41   NaN  0.51  1.60
# ...          ...   ...     ...   ...   ...   ...    ...   ...   ...   ...
# 2019-12-31  2.80  1.57    2.63  0.37  0.32  3.60   0.91  1.12  1.65  2.06
# 2020-03-31  3.09  1.49    2.39  0.34  0.31  2.71   1.03  1.11  1.53  1.90
# 2020-06-30  3.39  1.55    2.50  0.34  0.27  2.56   0.98  1.19  1.52  2.14
# 2020-09-30  3.96  1.44    2.41  0.41  0.24  1.71   0.98  1.24  1.65  1.92
# 2020-12-31   NaN   NaN     NaN   NaN   NaN   NaN    NaN   NaN   NaN  1.87
#
#             ...  COST   CVX    LLY   MCD   DHR   MDT   NEE   TXN   HON    UPS
# ...

# %%
df.resample('Q', convention = 'end').agg('mean').transpose()
# Out:
#        2005-03-31  2005-06-30  2005-09-30  2005-12-31  2006-03-31  2006-06-30  \
# AAPL         0.58        0.54        0.55        0.69        0.60        0.62
# MSFT         0.40        0.47        0.48        0.52        0.59        0.74
# AMZN       -16.26      -41.64      471.00       14.02        8.23        7.26
# GOOG         0.13        0.14        0.08        0.09        0.10        0.08
# FB            NaN         NaN         NaN         NaN         NaN         NaN
# TSLA          NaN         NaN         NaN         NaN         NaN         NaN
# BRK.A        1.21        1.21        1.20        1.17        1.41        1.38
# V             NaN         NaN         NaN         NaN         NaN         NaN
# JNJ          0.62        0.55        0.54        0.52        0.51        0.50
# WMT          1.43        1.59        1.61        1.64        1.60        1.64
# JPM         10.19       10.11       10.34       10.18       10.75       11.00
# ...

# %%
col = df.resample('Q', convention = 'end').agg('mean').transpose()['2020-09-30']

# %%
result = (col < 5) & (col > 0)

# %%
result.name = 'D/E Ratio'

# %%
result
# Out:
# AAPL      True
# MSFT      True
# AMZN      True
# GOOG      True
# FB        True
# TSLA      True
# BRK.A     True
# V         True
# JNJ       True
# WMT       True
# JPM      False
# MA        True
# PG        True
# UNH       True
# DIS       True
# NVDA      True
# HD       False
# PYPL      True
# BAC      False
# VZ        True
# ADBE      True
# CMCSA     True
# NFLX      True
# KO        True
# NKE       True
# MRK       True
# PEP      False
# T         True
# PFE       True
# INTC      True
# CRM       True
# ABT       True
# ORCL     False
# ABBV     False
# CSCO      True
# TMO       True
# AVGO      True
# XOM       True
# ACN       True
# QCOM      True
# COST      True
# CVX       True
# LLY      False
# MCD      False
# DHR       True
# MDT       True
# NEE       True
# TXN       True
# HON       True
# UPS      False
# Name: D/E Ratio, dtype: bool
